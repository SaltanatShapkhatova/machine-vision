# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
im = pltimg.imread('.\\6_26.jpg')
fig = plt.figure(figsize=(15,10))
plt.subplot(221)
plt.imshow(im[:,:,0])
plt.subplot(222)
plt.imshow(im[:,:,1])
plt.subplot(223)
plt.imshow(im[:,:,2])
plt.subplot(224)
plt.imshow(im)
plt.show()

# %%
im = pltimg.imread('.\\6_26.jpg')
fig = plt.figure()
plt.subplot(121)
plt.plot(im[:,1000,1])
plt.subplot(122)
plt.imshow(im)
plt.show()

# %%
im = pltimg.imread('.\\6_26.jpg')
plt.subplot(121)
plt.imshow(im[230:600, 870:1220])
plt.subplot(122)
plt.imshow(im[0:400, 0:1000])
plt.show()

# %%
temp = pltimg.imread('.\\6_26.jpg')
img1 = pltimg.imread('.\\6_26.jpg')
fig = plt.figure(figsize=(15,10))

#GRB
fig = plt.figure(figsize=(15,10))
plt.subplot(231)
temp[:,:,0] = img1[:,:,1]
temp[:,:,1] = img1[:,:,0]
plt.imshow(temp)
plt.show()

#BRG
fig = plt.figure(figsize=(15,10))
plt.subplot(232)
temp[:,:,0] = im[:,:,2]
temp[:,:,1] = im[:,:,0]
temp[:,:,2] = im[:,:,1]
plt.imshow(temp)
plt.show()

#GBR
fig = plt.figure(figsize=(15,10))
plt.subplot(233)
temp[:,:,0] = im[:,:,1]
temp[:,:,1] = im[:,:,2]
temp[:,:,2] = im[:,:,0]
plt.imshow(temp)
plt.show()

#BGR
fig = plt.figure(figsize=(15,10))
plt.subplot(234)
temp[:,:,0] = im[:,:,2]
temp[:,:,2] = im[:,:,0]
plt.imshow(temp)
plt.show()

#RBG
fig = plt.figure(figsize=(15,10))
plt.subplot(235)
temp[:,:,1] = im[:,:,2]
temp[:,:,2] = im[:,:,1]
plt.imshow(temp)
plt.show()

# %%
img = pltimg.imread('.\\6_26.jpg')
temp = pltimg.imread('.\\6_26.jpg')
plt.subplot(111)
img[1030:1400, 250:750, :] = temp[230:600, 750:1250, :] 
plt.imshow(img)
plt.show()
